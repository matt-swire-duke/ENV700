# %% [markdown]
# ```
# ENV 700: Environmental Data Exploration - Python
# Fall 2026 -- Instructor: John Fay
# ```
#
# # Python Fundamentals Practice
#
# This optional practice notebook is designed to help you prepare for the Python Fundamentals Assessment. It uses environmental-data examples, but the goal is to practice the core Python skills—not to memorize these particular questions.
#
# **How to use this notebook**
#
# 1. Work through the sections in order.
# 2. Write your own code in the cells marked **Your work**.
# 3. Run each cell and compare your result with the stated check.
# 4. If you get stuck, review the relevant lesson notebook and try again before looking for help.
#
# You should be comfortable adapting these skills to a new context before beginning the graded assessment.

# %% [markdown]
# ## Skills to practice
#
# By the end, you should be able to:
#
# - communicate clearly with Markdown;
# - create, inspect, and combine values with variables;
# - choose and use Python collection types;
# - make decisions with conditional statements;
# - repeat work with `for` and `while` loops; and
# - define and call functions that return useful values.

# %% [markdown]
# ---
# # 1. Markdown for clear notebook communication
#
# Create a **new Markdown cell** directly below this one that presents a short field-note card for an imaginary sampling visit. Include:
#
# - a level-2 heading named **Field Visit**;
# - one short sentence with a word in **bold**;
# - a numbered list of three preparation steps; and
# - a link to the USGS website (https://www.usgs.gov/)
#
# *Check:* When rendered, the cell should look like a small, readable set of notes rather than plain text.

# %% [markdown]
# ## Field Visit
#
# Righting a short sentence with a **bold** in it.
#
# List for preperation
# 1. Cut the vegtables
# 2. Cook the vegtables
# 3. Finish the vegtables
#
# Here's a link to [USGS](https://www.usgs.gov/)

# %% [markdown]
# ---
# # 2. Variables, values, and types
#
# A field crew records a stream-water temperature of `18.6` degrees Celsius and visits the site named `"Little River"`.
#
# In the next cell:
#
# 1. Store the temperature and site name in clearly named variables.
# 2. Create a variable named `temperature_f` that converts the Celsius temperature to Fahrenheit using `F = C × 9 / 5 + 32`.
# 3. Print one sentence that reports the site and both temperatures.
# 4. Use `type()` to inspect the temperature, site name, and converted temperature.
#
# *Check:* `temperature_f` should be approximately `65.48`, and the two temperatures should be numeric values while the site name is text.

# %%
# Write your code here

site_name = "Little River"
temp_c = 18.6
temp_f = temp_c * 9 / 5+ 32

print("Temperature conversion:",temp_f,"F")

print("The temperature of ",temp_c,"C is equivalent to ",temp_f,"F.",sep="")

print(type(site_name))
print(type(temp_f))
# Out:
# Temperature conversion: 65.48 F
# The temperature of 18.6C is equivalent to 65.48F.
# <class 'str'>
# <class 'float'>

# %% [markdown]
# ---
# ## 💥New Topic: Formatting output with `print()`💥
#
# The `print()` function can display several values at once by separating them with commas. Python automatically places a space between the values:

# %%
site = "Duke Forest"
pH = 6.8

print("Site:", site,"pH:", pH)
# Out:
# Site: Duke Forest pH: 6.8

# %% [markdown]
# For more control, use an f-string. Place an f before the opening quotation mark and put variable names inside curly braces:

# %%
print(f"Site: {site}; pH: {pH}")
# Out:
# Site: Duke Forest; pH: 6.8

# %% [markdown]
# F-strings make it easy to combine text and variables in a readable format. They also allow values to be formatted—for example, to display a number with two decimal places:

# %%
print(f"Site: {site}; pH: {pH:.2f}")
# Out:
# Site: Duke Forest; pH: 6.80

# %% [markdown]
# ---
# # 3. Choosing collection types
#
# A project has the following information:
#
# - the coordinates reference system is `"EPSG:4326"`;
# - three sampled species are `"Brook trout"`, `"River otter"`, and `"Wood frog"`;
# - the wetland classes observed are `"forest"`, `"emergent"`, `"shrub"`, and another `"forest"`; and
# - one monitoring site has identifier `"BR-14"`, elevation `412`, and is currently active.
#
# In the next cell:
#
# 1. Store the coordinate reference system in a **tuple** with the datum name `"WGS 84"`.
# 2. Store the species in a **list**, then replace `"Wood frog"` with `"Spring peeper"`.
# 3. Store the wetland classes in a **set** and print it. What happens to the repeated class?
# 4. Store the site details in a **dictionary** using sensible keys. Print only the elevation by looking it up with its key.
# 5. Print the first species in your updated list.
#
# *Check:* Your set should contain three unique wetland classes, and the reported elevation should be `412`.

# %%
# Write your code here
crs = ("EPSG:4326","WGS 84")
species = ['Brook trout','River otter','Wood frog']
wetland_classes = {'forest','emergent','shrub','forest'}

site_details = {
    'name': 'BR-14',
    'elevation':412,
    'active':True
    }

print(species[0])
print(site_details['elevation'])
# Out:
# Brook trout
# 412

# %% [markdown]
# ----
# # 4. Conditional decisions
#
# A soil-moisture sensor reports a percentage from 0 to 100. Create a variable named `soil_moisture` and give it a value of your choice. Then use `if`, `elif`, and `else` to print one of these field recommendations:
#
# - `"Irrigate"` when the value is below 25;
# - `"Monitor"` when the value is from 25 through 60;
# - `"No irrigation needed"` when the value is above 60.
#
# Test your code with at least two different values.
#
# *Check:* Boundary values matter: `25` should print `"Monitor"`, and `60` should also print `"Monitor"`.

# %%
# Write your code here
soil_moisture = 25

if soil_moisture < 25:
    print ("Irrigate")
elif soil_moisture <= 60:
    print("Monitor")
else:
    print ("No irrigation needed")
# Out:
# Monitor

# %% [markdown]
# ---
# # 5. Repeating work with loops
#
# Use the list below in the next cell:
#
# ```python
# weekly_rainfall_mm = [4.2, 0.0, 12.7, 8.1, 3.5]
# ```
#
# Complete each task:
#
# 1. Use a `for` loop to print a sentence for each week, such as `Week 1: 4.2 mm`.
# 2. Use a `for` loop to calculate the total rainfall without using `sum()`. Print the total after the loop.
# 3. Starting with `sample_number = 0`, use a `while` loop to print the sample numbers `0`, `1`, and `2`.
#
# *Check:* The total rainfall should be `28.5 mm`, and your `while` loop should stop after printing `2`.

# %%
weekly_rainfall_mm = [4.2, 0.0, 12.7, 8.1, 3.5]

# Your work
#need to set up a variable to go through everything; that variable changes with each iteration of the loop

total_rain = 0 
for rain in weekly_rainfall_mm:
   total_rain = total_rain + rain 
   #note: could also do total_rain += rain as a shortcun 

print(total_rain)
# Out:
# 28.5

# %%
sample_number = 0 

while sample_number < 3: 
    print(sample_number)
    sample_number += 1
# Out:
# 0
# 1
# 2

# %% [markdown]
# ---
# ## 💥New topic: Using `enumerate()` in `for` loops💥
#
# When looping through a list, `enumerate()` lets you access both the position and the value of each item:

# %%
sites = ["Duke Forest", "Jordan Lake", "Eno River"]

for index, site in enumerate(sites):
    print(index, site)
# Out:
# 0 Duke Forest
# 1 Jordan Lake
# 2 Eno River

# %% [markdown]
# The index starts at 0 by default. To start counting at a different number, use the start argument:

# %%
for number, site in enumerate(sites, start=1):
    print(f"{number}. {site}")
# Out:
# 1. Duke Forest
# 2. Jordan Lake
# 3. Eno River

# %% [markdown]
# Using enumerate() is often clearer and safer than manually creating and updating a counter variable.

# %%
#Use a `for` loop & enumerate() to print a sentence for each week, such as `Week 1: 4.2 mm`.

weekly_rainfall_mm = [4.2, 0.0, 12.7, 8.1, 3.5]

for week, rainfall in enumerate(weekly_rainfall_mm):
    print("Week:",week+1,',',rainfall)
# Out:
# Week: 1 , 4.2
# Week: 2 , 0.0
# Week: 3 , 12.7
# Week: 4 , 8.1
# Week: 5 , 3.5

# %% [markdown]
# ---
# # 6. Functions that package reusable work
#
# Write and test each function below. ~~Include a short docstring in each function that explains what it returns.~~
#
# ### A. One input
#
# Create `meters_to_kilometers(meters)`, which returns meters converted to kilometers. Test it with `1250`; the result should be `1.25`.
#
# ### B. Two inputs
#
# Create `observation_rate(observations, hours)`, which returns the number of observations per hour. Test it with `18` observations over `3` hours; the result should be `6.0`.
#
# ### C. Two returned values
#
# Create `first_last(values)`, which accepts a list and returns its first and last items. Test it with a list of at least four values, storing the two returned results in separate variables before printing them.
#
# *Check:* Your functions should **return** values; they should not only print values inside the function.

# %%
#A - 1 input
def meters_to_kilometers(meters):
    kilometers = meters / 1000
    return kilometers

meters = 150
print("Meters:",(meters))
print( "Kilometers:",meters_to_kilometers(meters))
# Out:
# Meters: 150
# Kilometers: 0.15

# %%
#B - 2 inputs 
def observation_rate (observations,hour):
    observations_per_hour= observations / hour
    return observations_per_hour

observations = 18
hour = 3

print("Fun things seen in the universe!:", observation_rate(observations, hour))
# Out:
# Fun things seen in the universe!: 6.0

# %%
#C - 2 returned values
values = [1,2,3,6,9]

def first_last(values):
    return values[0],values [4]

print("First value: ",first_last(values))
# Out:
# First value:  (1, 9)

# %% [markdown]
# ---
# # 7. Integration challenge
#
# The following list contains the number of pollinators observed in four 10-minute surveys:
#
# ```python
# pollinator_counts = [7, 12, 4, 15]
# ```
#
# Write a short program that:
#
# 1. Defines a function called `survey_summary(counts)` that returns the total number of pollinators and the average per survey.
# 2. Calls the function and stores both returned values.
# 3. Uses a conditional statement to print `"High activity"` if the average is at least 10; otherwise print `"Lower activity"`.
# 4. Uses a `for` loop to print each survey's count.
#
# *Check:* For the supplied values, the total is `38`, the average is `9.5`, and the activity message is `"Lower activity"`.

# %%
pollinator_counts = [7, 12, 4, 15]

def survey_summary(pollinator_counts):
    total_pollinator = sum(pollinator_counts)
    average_pollinator = sum(pollinator_counts)/len(pollinator_counts)
    return total_pollinator, average_pollinator

total_pollinator, average_pollinator = survey_summary(pollinator_counts)

survey_summary(pollinator_counts)

print("Total pollinator:",total_pollinator)
print("Average pollinator:",average_pollinator)

if average_pollinator >= 10: 
    print("High activity")
else:
    print("Low activity")

position = 0
for count in pollinator_counts:
    position = position + 1
    print ("Pollinator #",position,": ", count, sep="")
# Out:
# Total pollinator: 38
# Average pollinator: 9.5
# Low activity
# Pollinator #1: 7
# Pollinator #2: 12
# Pollinator #3: 4
# Pollinator #4: 15

# %% [markdown]
# # Readiness check
#
# Before starting the graded assessment, make sure you can do each of the following without copying from this notebook:
#
# - explain why you selected a particular collection type;
# - trace what a conditional does at a boundary value;
# - explain how a loop variable changes;
# - distinguish printing a value from returning a value; and
# - create a new Markdown cell and format it intentionally.
#
# If one of these still feels uncertain, revisit the related lesson section and repeat the matching practice exercise with different values.
